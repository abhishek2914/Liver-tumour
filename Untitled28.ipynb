# %%
# !wget https://www.dropbox.com/scl/fi/wnkjljzosgf03sfeh84sw/Data2-1.zip?rlkey=jbn3610kth7poc6dmqa6eo1f1&st=mg5jaluh&dl=0
# Out:
# --2024-04-19 15:00:27--  https://www.dropbox.com/scl/fi/wnkjljzosgf03sfeh84sw/Data2-1.zip?rlkey=jbn3610kth7poc6dmqa6eo1f1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca03404324c560ddbc1d1102cf6.dl.dropboxusercontent.com/cd/0/inline/CRWocM9r7C1pWzUCXVOPYuEDpAKzoX-2fQ4_vDoSK9Xh-nGd3d0vW-_eyd9A24u_s6kBkHX82fmnecrs2Znmr74W5x6etoDM4yPIfi5SsM8z1QeAE3IM5K19YdOmwyW4NFzwYgF-lk_WX3mNSdcb9FtV/file# [following]
# --2024-04-19 15:00:28--  https://uca03404324c560ddbc1d1102cf6.dl.dropboxusercontent.com/cd/0/inline/CRWocM9r7C1pWzUCXVOPYuEDpAKzoX-2fQ4_vDoSK9Xh-nGd3d0vW-_eyd9A24u_s6kBkHX82fmnecrs2Znmr74W5x6etoDM4yPIfi5SsM8z1QeAE3IM5K19YdOmwyW4NFzwYgF-lk_WX3mNSdcb9FtV/file
# Resolving uca03404324c560ddbc1d1102cf6.dl.dropboxusercontent.com (uca03404324c560ddbc1d1102cf6.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uca03404324c560ddbc1d1102cf6.dl.dropboxusercontent.com (uca03404324c560ddbc1d1102cf6.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CRXgfA2inLwjbjqWf7MVTgbsY5Nytv9qeJdxeJ95EDsng4EeOFmCzdixojmobP7F9cQ0J-hOXX0y0rxBYJOMk_ZK7eiFE1CrrTe5jOw1rujx8564uFUPn9b-6vlnZQ0qjPy4XGdZ9XPAAB9iFrRIB7TY3gb9BAiyVmzIZ7ylBQYo2L6VhKVq-goyHI1QQe-UgijKxrpmJCI4JvEJrKLaG1gI1W0TXewiMqP9ZZTKDVN8jB8kBZu_BlM1rkPe24nbCSec8r0tPs2Os5EEnA_jmt9e6_KAJFBOEcn-aWbBOQyQZqpBuE0Qit7NS8kNuHY5kug1mYuRsyfaf9mJ2F9xlaNgH38U2LHfkaFSWaGmjdk7wg3hXfaFZhAWNSLM09GCE5E/file [following]
# --2024-04-19 15:00:28--  https://uca03404324c560ddbc1d1102cf6.dl.dropboxusercontent.com/cd/0/inline2/CRXgfA2inLwjbjqWf7MVTgbsY5Nytv9qeJdxeJ95EDsng4EeOFmCzdixojmobP7F9cQ0J-hOXX0y0rxBYJOMk_ZK7eiFE1CrrTe5jOw1rujx8564uFUPn9b-6vlnZQ0qjPy4XGdZ9XPAAB9iFrRIB7TY3gb9BAiyVmzIZ7ylBQYo2L6VhKVq-goyHI1QQe-UgijKxrpmJCI4JvEJrKLaG1gI1W0TXewiMqP9ZZTKDVN8jB8kBZu_BlM1rkPe24nbCSec8r0tPs2Os5EEnA_jmt9e6_KAJFBOEcn-aWbBOQyQZqpBuE0Qit7NS8kNuHY5kug1mYuRsyfaf9mJ2F9xlaNgH38U2LHfkaFSWaGmjdk7wg3hXfaFZhAWNSLM09GCE5E/file
# Reusing existing connection to uca03404324c560ddbc1d1102cf6.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2225990815 (2.1G) [application/zip]
# Saving to: ‘Data2-1.zip?rlkey=jbn3610kth7poc6dmqa6eo1f1’
#
# Data2-1.zip?rlkey=j 100%[===================>]   2.07G  90.5MB/s    in 30s
#
# 2024-04-19 15:00:58 (71.1 MB/s) - ‘Data2-1.zip?rlkey=jbn3610kth7poc6dmqa6eo1f1’ saved [2225990815/2225990815]

# %%
# !unzip /content/Data2-1.zip?rlkey=jbn3610kth7poc6dmqa6eo1f1
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/train_images/tumor/volume-15_slice_334.jpg
#   inflating: content/train_images/tumor/volume-18_slice_20.jpg
#   inflating: content/train_images/tumor/volume-23_slice_138.jpg
#   inflating: content/train_images/tumor/volume-6_slice_468.jpg
#   inflating: content/train_images/tumor/volume-21_slice_202.jpg
#   inflating: content/train_images/tumor/volume-22_slice_216.jpg
#   inflating: content/train_images/tumor/volume-8_slice_456.jpg
#   inflating: content/train_images/tumor/volume-11_slice_172.jpg
#   inflating: content/train_images/tumor/volume-25_slice_156.jpg
#   inflating: content/train_images/tumor/volume-11_slice_404.jpg
#   inflating: content/train_images/tumor/volume-3_slice_256.jpg
#   inflating: content/train_images/tumor/volume-40_slice_34.jpg
#   inflating: content/train_images/tumor/volume-6_slice_168.jpg
#   inflating: content/train_images/tumor/volume-8_slice_40.jpg
#   inflating: content/train_images/tumor/volume-4_slice_128.jpg
#   inflating: content/train_images/tumor/volume-4_slice_704.jpg
#   inflating: content/train_images/tumor/volume-22_slice_72.jpg
#   inflating: content/train_images/tumor/volume-48_slice_200.jpg
#   inflating: content/train_images/tumor/volume-2_slice_138.jpg
#   inflating: content/train_images/tumor/volume-19_slice_92.jpg
#   inflating: content/train_images/tumor/volume-26_slice_420.jpg
#   inflating: content/train_images/tumor/volume-13_slice_588.jpg
#   inflating: content/train_images/tumor/volume-3_slice_252.jpg
#   inflating: content/train_images/tumor/volume-3_slice_464.jpg
#   inflating: content/train_images/tumor/volume-17_slice_126.jpg
#   inflating: content/train_images/tumor/volume-9_slice_6.jpg
#   inflating: content/train_images/tumor/volume-15_slice_406.jpg
#   inflating: content/train_images/tumor/volume-25_slice_36.jpg
#   inflating: content/train_images/tumor/volume-15_slice_28.jpg
#   inflating: content/train_images/tumor/volume-14_slice_468.jpg
#   inflating: content/train_images/tumor/volume-26_slice_466.jpg
#   inflating: content/train_images/tumor/volume-26_slice_272.jpg
#   inflating: content/train_images/tumor/volume-8_slice_342.jpg
#   inflating: content/train_images/tumor/volume-11_slice_190.jpg
#   inflating: content/train_images/tumor/volume-9_slice_260.jpg
#   inflating: content/train_images/tumor/volume-39_slice_28.jpg
#   inflating: content/train_images/tumor/volume-24_slice_70.jpg
#   inflating: content/train_images/tumor/volume-25_slice_570.jpg
#   inflating: content/train_images/tumor/volume-18_slice_60.jpg
#   inflating: content/train_images/tumor/volume-6_slice_34.jpg
#   inflating: content/train_images/tumor/volume-6_slice_12.jpg
#   inflating: content/train_images/tumor/volume-23_slice_106.jpg
#   inflating: content/train_images/tumor/volume-6_slice_26.jpg
#   inflating: content/train_images/tumor/volume-17_slice_248.jpg
#   inflating: content/train_images/tumor/volume-16_slice_626.jpg
#   inflating: content/train_images/tumor/volume-36_slice_8.jpg
#   inflating: content/train_images/tumor/volume-18_slice_492.jpg
#   inflating: content/train_images/tumor/volume-3_slice_34.jpg
#   inflating: content/train_images/tumor/volume-7_slice_176.jpg
#   inflating: content/train_images/tumor/volume-16_slice_658.jpg
#   inflating: content/train_images/tumor/volume-7_slice_496.jpg
#   inflating: content/train_images/tumor/volume-48_slice_122.jpg
#   inflating: content/train_images/tumor/volume-26_slice_136.jpg
#   inflating: content/train_images/tumor/volume-6_slice_196.jpg
#   inflating: content/train_images/tumor/volume-19_slice_22.jpg
#   inflating: content/train_images/tumor/volume-20_slice_436.jpg
#   inflating: content/train_images/tumor/volume-17_slice_788.jpg
#   inflating: content/train_images/tumor/volume-19_slice_68.jpg
#   inflating: content/train_images/tumor/volume-26_slice_88.jpg
#   inflating: content/train_images/tumor/volume-16_slice_262.jpg
#   inflating: content/train_images/tumor/volume-18_slice_384.jpg
#   inflating: content/train_images/tumor/volume-12_slice_148.jpg
#   inflating: content/train_images/tumor/volume-20_slice_248.jpg
#   inflating: content/train_images/tumor/volume-30_slice_44.jpg
#   inflating: content/train_images/tumor/volume-29_slice_142.jpg
#   inflating: content/train_images/tumor/volume-9_slice_422.jpg
#   inflating: content/train_images/tumor/volume-27_slice_722.jpg
#   inflating: content/train_images/tumor/volume-16_slice_504.jpg
#   inflating: content/train_images/tumor/volume-12_slice_102.jpg
#   inflating: content/train_images/tumor/volume-21_slice_186.jpg
#   inflating: content/train_images/tumor/volume-18_slice_108.jpg
#   inflating: content/train_images/tumor/volume-9_slice_198.jpg
#   inflating: content/train_images/tumor/volume-18_slice_336.jpg
#   inflating: content/train_images/tumor/volume-11_slice_184.jpg
#   inflating: content/train_images/tumor/volume-43_slice_68.jpg
#   inflating: content/train_images/tumor/volume-39_slice_112.jpg
#   inflating: content/train_images/tumor/volume-27_slice_736.jpg
#   inflating: content/train_images/tumor/volume-49_slice_178.jpg
#   inflating: content/train_images/tumor/volume-43_slice_56.jpg
#   inflating: content/train_images/tumor/volume-0_slice_22.jpg
#   inflating: content/train_images/tumor/volume-17_slice_198.jpg
#   inflating: content/train_images/tumor/volume-25_slice_296.jpg
#   inflating: content/train_images/tumor/volume-1_slice_12.jpg
#   inflating: content/train_images/tumor/volume-4_slice_708.jpg
#   inflating: content/train_images/tumor/volume-14_slice_314.jpg
#   inflating: content/train_images/tumor/volume-24_slice_166.jpg
#   inflating: content/train_images/tumor/volume-27_slice_748.jpg
#   inflating: content/train_images/tumor/volume-4_slice_28.jpg
#   inflating: content/train_images/tumor/volume-12_slice_36.jpg
#   inflating: content/train_images/tumor/volume-4_slice_812.jpg
#   inflating: content/train_images/tumor/volume-43_slice_8.jpg
#   inflating: content/train_images/tumor/volume-17_slice_214.jpg
#   inflating: content/train_images/tumor/volume-1_slice_50.jpg
#   inflating: content/train_images/tumor/volume-6_slice_146.jpg
#   inflating: content/train_images/tumor/volume-23_slice_90.jpg
#   inflating: content/train_images/tumor/volume-16_slice_278.jpg
#   inflating: content/train_images/tumor/volume-6_slice_214.jpg
#   inflating: content/train_images/tumor/volume-14_slice_342.jpg
#   inflating: content/train_images/tumor/volume-8_slice_124.jpg
#   inflating: content/train_images/tumor/volume-44_slice_84.jpg
#   inflating: content/train_images/tumor/volume-17_slice_256.jpg
#   inflating: content/train_images/tumor/volume-4_slice_608.jpg
#   inflating: content/train_images/tumor/volume-9_slice_358.jpg
#   inflating: content/train_images/tumor/volume-18_slice_714.jpg
#   inflating: content/train_images/tumor/volume-21_slice_344.jpg
#   inflating: content/train_images/tumor/volume-43_slice_116.jpg
#   inflating: content/train_images/tumor/volume-27_slice_584.jpg
#   inflating: content/train_images/tumor/volume-15_slice_24.jpg
#   inflating: content/train_images/tumor/volume-16_slice_448.jpg
#   inflating: content/train_images/tumor/volume-37_slice_6.jpg
#   inflating: content/train_images/tumor/volume-2_slice_178.jpg
#   inflating: content/train_images/tumor/volume-4_slice_220.jpg
#   inflating: content/train_images/tumor/volume-39_slice_198.jpg
#   inflating: content/train_images/tumor/volume-21_slice_420.jpg
#   inflating: content/train_images/tumor/volume-5_slice_154.jpg
#   inflating: content/train_images/tumor/volume-12_slice_412.jpg
#   inflating: content/train_images/tumor/volume-11_slice_420.jpg
#   inflating: content/train_images/tumor/volume-27_slice_112.jpg
#   inflating: content/train_images/tumor/volume-13_slice_136.jpg
#   inflating: content/train_images/tumor/volume-27_slice_306.jpg
#   inflating: content/train_images/tumor/volume-14_slice_282.jpg
#   inflating: content/train_images/tumor/volume-4_slice_76.jpg
#   inflating: content/train_images/tumor/volume-21_slice_292.jpg
#   inflating: content/train_images/tumor/volume-7_slice_478.jpg
#   inflating: content/train_images/tumor/volume-17_slice_770.jpg
#   inflating: content/train_images/tumor/volume-4_slice_716.jpg
#   inflating: content/train_images/tumor/volume-13_slice_404.jpg
#   inflating: content/train_images/tumor/volume-12_slice_192.jpg
#   inflating: content/train_images/tumor/volume-14_slice_196.jpg
#   inflating: content/train_images/tumor/volume-0_slice_30.jpg
#   inflating: content/train_images/tumor/volume-17_slice_90.jpg
#   inflating: content/train_images/tumor/volume-13_slice_450.jpg
#   inflating: content/train_images/tumor/volume-15_slice_478.jpg
#   inflating: content/train_images/tumor/volume-11_slice_136.jpg
#   inflating: content/train_images/tumor/volume-16_slice_442.jpg
#   inflating: content/train_images/tumor/volume-8_slice_392.jpg
#   inflating: content/train_images/tumor/volume-7_slice_78.jpg
#   inflating: content/train_images/tumor/volume-3_slice_88.jpg
#   inflating: content/train_images/tumor/volume-14_slice_396.jpg
#   inflating: content/train_images/tumor/volume-23_slice_150.jpg
#   inflating: content/train_images/tumor/volume-17_slice_228.jpg
#   inflating: content/train_images/tumor/volume-10_slice_442.jpg
#   inflating: content/train_images/tumor/volume-4_slice_702.jpg
#   inflating: content/train_images/tumor/volume-44_slice_56.jpg
#   inflating: content/train_images/tumor/volume-10_slice_338.jpg
#   inflating: content/train_images/tumor/volume-27_slice_740.jpg
#   inflating: content/train_images/tumor/volume-50_slice_62.jpg
#   inflating: content/train_images/tumor/volume-17_slice_422.jpg
#   inflating: content/train_images/tumor/volume-2_slice_136.jpg
#   inflating: content/train_images/tumor/volume-24_slice_156.jpg
#   inflating: content/train_images/tumor/volume-18_slice_720.jpg
#   inflating: content/train_images/tumor/volume-12_slice_30.jpg
#   inflating: content/train_images/tumor/volume-29_slice_66.jpg
#   inflating: content/train_images/tumor/volume-4_slice_392.jpg
#   inflating: content/train_images/tumor/volume-20_slice_124.jpg
#   inflating: content/train_images/tumor/volume-21_slice_378.jpg
#   inflating: content/train_images/tumor/volume-17_slice_282.jpg
#   inflating: content/train_images/tumor/volume-27_slice_614.jpg
#   inflating: content/train_images/tumor/volume-4_slice_524.jpg
#   inflating: content/train_images/tumor/volume-10_slice_418.jpg
#   inflating: content/train_images/tumor/volume-8_slice_32.jpg
#   inflating: content/train_images/tumor/volume-27_slice_510.jpg
#   inflating: content/train_images/tumor/volume-18_slice_234.jpg
#   inflating: content/train_images/tumor/volume-17_slice_76.jpg
#   inflating: content/train_images/tumor/volume-17_slice_582.jpg
#   inflating: content/train_images/tumor/volume-27_slice_296.jpg
#   inflating: content/train_images/tumor/volume-50_slice_102.jpg
#   inflating: content/train_images/tumor/volume-37_slice_16.jpg
#   inflating: content/train_images/tumor/volume-11_slice_438.jpg
#   inflating: content/train_images/tumor/volume-18_slice_386.jpg
#   inflating: content/train_images/tumor/volume-27_slice_14.jpg
#   inflating: content/train_images/tumor/volume-8_slice_516.jpg
#   inflating: content/train_images/tumor/volume-7_slice_444.jpg
#   inflating: content/train_images/tumor/volume-16_slice_618.jpg
#   inflating: content/train_images/tumor/volume-4_slice_614.jpg
#   inflating: content/train_images/tumor/volume-4_slice_776.jpg
#   inflating: content/train_images/tumor/volume-16_slice_674.jpg
#   inflating: content/train_images/tumor/volume-27_slice_160.jpg
#   inflating: content/train_images/tumor/volume-10_slice_142.jpg
#   inflating: content/train_images/tumor/volume-9_slice_22.jpg
#   inflating: content/train_images/tumor/volume-21_slice_430.jpg
#   inflating: content/train_images/tumor/volume-9_slice_330.jpg
#   inflating: content/train_images/tumor/volume-16_slice_352.jpg
#   inflating: content/train_images/tumor/volume-3_slice_158.jpg
#   inflating: content/train_images/tumor/volume-35_slice_4.jpg
#   inflating: content/train_images/tumor/volume-19_slice_242.jpg
#   inflating: content/train_images/tumor/volume-15_slice_438.jpg
#   inflating: content/train_images/tumor/volume-30_slice_72.jpg
#   inflating: content/train_images/tumor/volume-19_slice_360.jpg
#   inflating: content/train_images/tumor/volume-14_slice_366.jpg
#   inflating: content/train_images/tumor/volume-7_slice_242.jpg
#   inflating: content/train_images/tumor/volume-42_slice_4.jpg
#   inflating: content/train_images/tumor/volume-14_slice_536.jpg
#   inflating: content/train_images/tumor/volume-27_slice_290.jpg
#   inflating: content/train_images/tumor/volume-8_slice_510.jpg
#   inflating: content/train_images/tumor/volume-7_slice_26.jpg
#   inflating: content/train_images/tumor/volume-4_slice_92.jpg
#   inflating: content/train_images/tumor/volume-40_slice_66.jpg
#   inflating: content/train_images/tumor/volume-23_slice_300.jpg
#   inflating: content/train_images/tumor/volume-12_slice_188.jpg
#   inflating: content/train_images/tumor/volume-3_slice_306.jpg
#   inflating: content/train_images/tumor/volume-4_slice_260.jpg
#   inflating: content/train_images/tumor/volume-20_slice_22.jpg
#   inflating: content/train_images/tumor/volume-21_slice_410.jpg
#   inflating: content/train_images/tumor/volume-8_slice_420.jpg
#   inflating: content/train_images/tumor/volume-26_slice_422.jpg
#   inflating: content/train_images/tumor/volume-19_slice_74.jpg
#   inflating: content/train_images/tumor/volume-6_slice_400.jpg
#   inflating: content/train_images/tumor/volume-15_slice_552.jpg
#   inflating: content/train_images/tumor/volume-49_slice_148.jpg
#   inflating: content/train_images/tumor/volume-26_slice_226.jpg
#   inflating: content/train_images/tumor/volume-42_slice_14.jpg
#   inflating: content/train_images/tumor/volume-13_slice_112.jpg
#   inflating: content/train_images/tumor/volume-26_slice_404.jpg
#   inflating: content/train_images/tumor/volume-5_slice_238.jpg
#   inflating: content/train_images/tumor/volume-26_slice_566.jpg
#   inflating: content/train_images/tumor/volume-19_slice_76.jpg
#   inflating: content/train_images/tumor/volume-9_slice_336.jpg
#   inflating: content/train_images/tumor/volume-27_slice_470.jpg
#   inflating: content/train_images/tumor/volume-15_slice_150.jpg
#   inflating: content/train_images/tumor/volume-39_slice_124.jpg
#   inflating: content/train_images/tumor/volume-21_slice_2.jpg
#   inflating: content/train_images/tumor/volume-4_slice_172.jpg
#   inflating: content/train_images/tumor/volume-40_slice_84.jpg
#   inflating: content/train_images/tumor/volume-18_slice_692.jpg
#   inflating: content/train_images/tumor/volume-43_slice_76.jpg
#   inflating: content/train_images/tumor/volume-3_slice_340.jpg
#   inflating: content/train_images/tumor/volume-18_slice_552.jpg
#   inflating: content/train_images/tumor/volume-25_slice_438.jpg
#   inflating: content/train_images/tumor/volume-8_slice_26.jpg
#   inflating: content/train_images/tumor/volume-4_slice_112.jpg
#   inflating: content/train_images/tumor/volume-10_slice_112.jpg
#   inflating: content/train_images/tumor/volume-21_slice_82.jpg
#   inflating: content/train_images/tumor/volume-50_slice_28.jpg
#   inflating: content/train_images/tumor/volume-3_slice_446.jpg
#   inflating: content/train_images/tumor/volume-26_slice_328.jpg
#   inflating: content/train_images/tumor/volume-48_slice_134.jpg
#   inflating: content/train_images/tumor/volume-13_slice_4.jpg
#   inflating: content/train_images/tumor/volume-9_slice_390.jpg
#   inflating: content/train_images/tumor/volume-20_slice_116.jpg
#   inflating: content/train_images/tumor/volume-8_slice_312.jpg
#   inflating: content/train_images/tumor/volume-25_slice_120.jpg
#   inflating: content/train_images/tumor/volume-30_slice_70.jpg
#   inflating: content/train_images/tumor/volume-6_slice_120.jpg
#   inflating: content/train_images/tumor/volume-35_slice_118.jpg
#   inflating: content/train_images/tumor/volume-2_slice_346.jpg
#   inflating: content/train_images/tumor/volume-24_slice_108.jpg
#   inflating: content/train_images/tumor/volume-48_slice_126.jpg
#   inflating: content/train_images/tumor/volume-24_slice_162.jpg
#   inflating: content/train_images/tumor/volume-29_slice_88.jpg
#   inflating: content/train_images/tumor/volume-27_slice_428.jpg
#   inflating: content/train_images/tumor/volume-26_slice_382.jpg
#   inflating: content/train_images/tumor/volume-21_slice_218.jpg
#   inflating: content/train_images/tumor/volume-2_slice_318.jpg
#   inflating: content/train_images/tumor/volume-48_slice_188.jpg
#   inflating: content/train_images/tumor/volume-23_slice_204.jpg
#   inflating: content/train_images/tumor/volume-18_slice_106.jpg
#   inflating: content/train_images/tumor/volume-2_slice_182.jpg
#   inflating: content/train_images/tumor/volume-6_slice_432.jpg
#   inflating: content/train_images/tumor/volume-33_slice_98.jpg
#   inflating: content/train_images/tumor/volume-44_slice_36.jpg
#   inflating: content/train_images/tumor/volume-16_slice_434.jpg
#   inflating: content/train_images/tumor/volume-48_slice_14.jpg
#   inflating: content/train_images/tumor/volume-20_slice_8.jpg
#   inflating: content/train_images/tumor/volume-37_slice_10.jpg
#   inflating: content/train_images/tumor/volume-7_slice_282.jpg
#   inflating: content/train_images/tumor/volume-27_slice_298.jpg
#   inflating: content/train_images/tumor/volume-46_slice_96.jpg
#   inflating: content/train_images/tumor/volume-3_slice_504.jpg
#   inflating: content/train_images/tumor/volume-19_slice_224.jpg
#   inflating: content/train_images/tumor/volume-21_slice_334.jpg
#   inflating: content/train_images/tumor/volume-20_slice_176.jpg
#   inflating: content/train_images/tumor/volume-3_slice_222.jpg
#   inflating: content/train_images/tumor/volume-4_slice_314.jpg
#   inflating: content/train_images/tumor/volume-37_slice_18.jpg
#   inflating: content/train_images/tumor/volume-25_slice_146.jpg
#   inflating: content/train_images/tumor/volume-25_slice_416.jpg
#   inflating: content/train_images/tumor/volume-42_slice_102.jpg
#   inflating: content/train_images/tumor/volume-17_slice_796.jpg
#   inflating: content/train_images/tumor/volume-7_slice_538.jpg
#   inflating: content/train_images/tumor/volume-14_slice_182.jpg
#   inflating: content/train_images/tumor/volume-27_slice_562.jpg
#   inflating: content/train_images/tumor/volume-19_slice_440.jpg
#   inflating: content/train_images/tumor/volume-14_slice_244.jpg
#   inflating: content/train_images/tumor/volume-26_slice_546.jpg
#   inflating: content/train_images/tumor/volume-6_slice_252.jpg
#   inflating: content/train_images/tumor/volume-29_slice_162.jpg
#   inflating: content/train_images/tumor/volume-26_slice_562.jpg
#   inflating: content/train_images/tumor/volume-7_slice_482.jpg
#   inflating: content/train_images/tumor/volume-2_slice_478.jpg
#   inflating: content/train_images/tumor/volume-27_slice_498.jpg
#   inflating: content/train_images/tumor/volume-20_slice_280.jpg
#   inflating: content/train_images/tumor/volume-11_slice_32.jpg
#   inflating: content/train_images/tumor/volume-26_slice_568.jpg
#   inflating: content/train_images/tumor/volume-6_slice_326.jpg
#   inflating: content/train_images/tumor/volume-40_slice_62.jpg
#   inflating: content/train_images/tumor/volume-9_slice_116.jpg
#   inflating: content/train_images/tumor/volume-4_slice_804.jpg
#   inflating: content/train_images/tumor/volume-7_slice_256.jpg
#   inflating: content/train_images/tumor/volume-46_slice_22.jpg
#   inflating: content/train_images/tumor/volume-26_slice_608.jpg
#   inflating: content/train_images/tumor/volume-31_slice_56.jpg
#   inflating: content/train_images/tumor/volume-2_slice_362.jpg
#   inflating: content/train_images/tumor/volume-49_slice_222.jpg
#   inflating: content/train_images/tumor/volume-12_slice_270.jpg
#   inflating: content/train_images/tumor/volume-15_slice_148.jpg
#   inflating: content/train_images/tumor/volume-11_slice_358.jpg
#   inflating: content/train_images/tumor/volume-17_slice_380.jpg
#   inflating: content/train_images/tumor/volume-5_slice_24.jpg
#   inflating: content/train_images/tumor/volume-50_slice_150.jpg
#   inflating: content/train_images/tumor/volume-17_slice_518.jpg
#   inflating: content/train_images/tumor/volume-39_slice_152.jpg
#   inflating: content/train_images/tumor/volume-10_slice_454.jpg
#   inflating: content/train_images/tumor/volume-13_slice_490.jpg
#   inflating: content/train_images/tumor/volume-9_slice_300.jpg
#   inflating: content/train_images/tumor/volume-39_slice_84.jpg
#   inflating: content/train_images/tumor/volume-35_slice_94.jpg
#   inflating: content/train_images/tumor/volume-17_slice_790.jpg
#   inflating: content/train_images/tumor/volume-20_slice_216.jpg
#   inflating: content/train_images/tumor/volume-17_slice_338.jpg
#   inflating: content/train_images/tumor/volume-39_slice_252.jpg
#   inflating: content/train_images/tumor/volume-20_slice_186.jpg
#   inflating: content/train_images/tumor/volume-25_slice_148.jpg
#   inflating: content/train_images/tumor/volume-26_slice_28.jpg
#   inflating: content/train_images/tumor/volume-14_slice_198.jpg
#   inflating: content/train_images/tumor/volume-19_slice_282.jpg
#   inflating: content/train_images/tumor/volume-39_slice_110.jpg
#   inflating: content/train_images/tumor/volume-26_slice_368.jpg
#   inflating: content/train_images/tumor/volume-13_slice_64.jpg
#   inflating: content/train_images/tumor/volume-37_slice_98.jpg
#   inflating: content/train_images/tumor/volume-5_slice_190.jpg
#   inflating: content/train_images/tumor/volume-15_slice_540.jpg
#   inflating: content/train_images/tumor/volume-9_slice_408.jpg
#   inflating: content/train_images/tumor/volume-8_slice_360.jpg
#   inflating: content/train_images/tumor/volume-22_slice_34.jpg
#   inflating: content/train_images/tumor/volume-21_slice_380.jpg
#   inflating: content/train_images/tumor/volume-7_slice_456.jpg
#   inflating: content/train_images/tumor/volume-1_slice_36.jpg
#   inflating: content/train_images/tumor/volume-15_slice_542.jpg
#   inflating: content/train_images/tumor/volume-27_slice_218.jpg
#   inflating: content/train_images/tumor/volume-27_slice_828.jpg
#   inflating: content/train_images/tumor/volume-27_slice_188.jpg
#   inflating: content/train_images/tumor/volume-8_slice_18.jpg
#   inflating: content/train_images/tumor/volume-4_slice_748.jpg
#   inflating: content/train_images/tumor/volume-5_slice_184.jpg
#   inflating: content/train_images/tumor/volume-6_slice_456.jpg
#   inflating: content/train_images/tumor/volume-4_slice_688.jpg
#   inflating: content/train_images/tumor/volume-12_slice_356.jpg
#   inflating: content/train_images/tumor/volume-19_slice_482.jpg
#   inflating: content/train_images/tumor/volume-18_slice_356.jpg
#   inflating: content/train_images/tumor/volume-11_slice_96.jpg
#   inflating: content/train_images/tumor/volume-19_slice_500.jpg
#   inflating: content/train_images/tumor/volume-25_slice_522.jpg
#   inflating: content/train_images/tumor/volume-19_slice_20.jpg
#   inflating: content/train_images/tumor/volume-12_slice_418.jpg
#   inflating: content/train_images/tumor/volume-4_slice_806.jpg
#   inflating: content/train_images/tumor/volume-10_slice_416.jpg
#   inflating: content/train_images/tumor/volume-16_slice_600.jpg
#   inflating: content/train_images/tumor/volume-19_slice_326.jpg
#   inflating: content/train_images/tumor/volume-12_slice_222.jpg
#   inflating: content/train_images/tumor/volume-0_slice_40.jpg
#   inflating: content/train_images/tumor/volume-18_slice_350.jpg
#   inflating: content/train_images/tumor/volume-16_slice_510.jpg
#   inflating: content/train_images/tumor/volume-4_slice_372.jpg
#   inflating: content/train_images/tumor/volume-11_slice_268.jpg
#   inflating: content/train_images/tumor/volume-13_slice_342.jpg
#   inflating: content/train_images/tumor/volume-7_slice_200.jpg
#   inflating: content/train_images/tumor/volume-16_slice_270.jpg
#   inflating: content/train_images/tumor/volume-23_slice_298.jpg
#   inflating: content/train_images/tumor/volume-27_slice_770.jpg
#   inflating: content/train_images/tumor/volume-13_slice_46.jpg
#   inflating: content/train_images/tumor/volume-17_slice_134.jpg
#   inflating: content/train_images/tumor/volume-2_slice_276.jpg
#   inflating: content/train_images/tumor/volume-19_slice_544.jpg
#   inflating: content/train_images/tumor/volume-10_slice_74.jpg
#   inflating: content/train_images/tumor/volume-21_slice_184.jpg
#   inflating: content/train_images/tumor/volume-16_slice_564.jpg
#   inflating: content/train_images/tumor/volume-14_slice_68.jpg
#   inflating: content/train_images/tumor/volume-12_slice_212.jpg
#   inflating: content/train_images/tumor/volume-7_slice_210.jpg
#   inflating: content/train_images/tumor/volume-8_slice_122.jpg
#   inflating: content/train_images/tumor/volume-42_slice_28.jpg
#   inflating: content/train_images/tumor/volume-22_slice_108.jpg
#   inflating: content/train_images/tumor/volume-16_slice_514.jpg
#   inflating: content/train_images/tumor/volume-50_slice_48.jpg
#   inflating: content/train_images/tumor/volume-43_slice_44.jpg
#   inflating: content/train_images/tumor/volume-4_slice_376.jpg
#   inflating: content/train_images/tumor/volume-7_slice_506.jpg
#   inflating: content/train_images/tumor/volume-12_slice_40.jpg
#   inflating: content/train_images/tumor/volume-25_slice_412.jpg
#   inflating: content/train_images/tumor/volume-9_slice_474.jpg
#   inflating: content/train_images/tumor/volume-16_slice_80.jpg
#   inflating: content/train_images/tumor/volume-3_slice_376.jpg
#   inflating: content/train_images/tumor/volume-10_slice_86.jpg
#   inflating: content/train_images/tumor/volume-1_slice_60.jpg
#   inflating: content/train_images/tumor/volume-50_slice_100.jpg
#   inflating: content/train_images/tumor/volume-4_slice_384.jpg
#   inflating: content/train_images/tumor/volume-40_slice_118.jpg
#   inflating: content/train_images/tumor/volume-40_slice_102.jpg
#   inflating: content/train_images/tumor/volume-26_slice_246.jpg
#   inflating: content/train_images/tumor/volume-6_slice_284.jpg
#   inflating: content/train_images/tumor/volume-26_slice_86.jpg
#   inflating: content/train_images/tumor/volume-6_slice_118.jpg
#   inflating: content/train_images/tumor/volume-25_slice_236.jpg
#   inflating: content/train_images/tumor/volume-19_slice_400.jpg
#   inflating: content/train_images/tumor/volume-25_slice_332.jpg
#   inflating: content/train_images/tumor/volume-25_slice_480.jpg
#   inflating: content/train_images/tumor/volume-17_slice_246.jpg
#   inflating: content/train_images/tumor/volume-17_slice_370.jpg
#   inflating: content/train_images/tumor/volume-8_slice_340.jpg
#   inflating: content/train_images/tumor/volume-26_slice_398.jpg
#   inflating: content/train_images/tumor/volume-8_slice_304.jpg
#   inflating: content/train_images/tumor/volume-16_slice_104.jpg
#   inflating: content/train_images/tumor/volume-11_slice_274.jpg
#   inflating: content/train_images/tumor/volume-1_slice_26.jpg
#   inflating: content/train_images/tumor/volume-12_slice_34.jpg
#   inflating: content/train_images/tumor/volume-3_slice_426.jpg
#   inflating: content/train_images/tumor/volume-25_slice_80.jpg
#   inflating: content/train_images/tumor/volume-21_slice_382.jpg
#   inflating: content/train_images/tumor/volume-36_slice_84.jpg
#   inflating: content/train_images/tumor/volume-5_slice_152.jpg
#   inflating: content/train_images/tumor/volume-10_slice_272.jpg
#   inflating: content/train_images/tumor/volume-14_slice_260.jpg
#   inflating: content/train_images/tumor/volume-0_slice_50.jpg
#   inflating: content/train_images/tumor/volume-9_slice_490.jpg
#   inflating: content/train_images/tumor/volume-30_slice_88.jpg
#   inflating: content/train_images/tumor/volume-23_slice_66.jpg
#   inflating: content/train_images/tumor/volume-25_slice_364.jpg
#   inflating: content/train_images/tumor/volume-14_slice_338.jpg
#   inflating: content/train_images/tumor/volume-16_slice_44.jpg
#   inflating: content/train_images/tumor/volume-9_slice_362.jpg
#   inflating: content/train_images/tumor/volume-25_slice_512.jpg
#   inflating: content/train_images/tumor/volume-4_slice_264.jpg
#   inflating: content/train_images/tumor/volume-50_slice_170.jpg
#   inflating: content/train_images/tumor/volume-13_slice_578.jpg
#   inflating: content/train_images/tumor/volume-9_slice_378.jpg
#   inflating: content/train_images/tumor/volume-27_slice_574.jpg
#   inflating: content/train_images/tumor/volume-27_slice_312.jpg
#   inflating: content/train_images/tumor/volume-13_slice_344.jpg
#   inflating: content/train_images/tumor/volume-2_slice_8.jpg
#   inflating: content/train_images/tumor/volume-13_slice_172.jpg
#   inflating: content/train_images/tumor/volume-5_slice_430.jpg
#   inflating: content/train_images/tumor/volume-24_slice_194.jpg
#   inflating: content/train_images/tumor/volume-6_slice_16.jpg
#   inflating: content/train_images/tumor/volume-8_slice_442.jpg
#   inflating: content/train_images/tumor/volume-46_slice_94.jpg
#   inflating: content/train_images/tumor/volume-24_slice_252.jpg
#   inflating: content/train_images/tumor/volume-15_slice_376.jpg
#   inflating: content/train_images/tumor/volume-11_slice_428.jpg
#   inflating: content/train_images/tumor/volume-21_slice_48.jpg
#   inflating: content/train_images/tumor/volume-6_slice_194.jpg
#   inflating: content/train_images/tumor/volume-44_slice_22.jpg
#   inflating: content/train_images/tumor/volume-26_slice_560.jpg
#   inflating: content/train_images/tumor/volume-27_slice_476.jpg
#   inflating: content/train_images/tumor/volume-39_slice_222.jpg
#   inflating: content/train_images/tumor/volume-4_slice_568.jpg
#   inflating: content/train_images/tumor/volume-11_slice_400.jpg
#   inflating: content/train_images/tumor/volume-17_slice_612.jpg
#   inflating: content/train_images/tumor/volume-26_slice_46.jpg
#   inflating: content/train_images/tumor/volume-45_slice_46.jpg
#   inflating: content/train_images/tumor/volume-13_slice_48.jpg
#   inflating: content/train_images/tumor/volume-17_slice_456.jpg
#   inflating: content/train_images/tumor/volume-9_slice_124.jpg
#   inflating: content/train_images/tumor/volume-4_slice_84.jpg
#   inflating: content/train_images/tumor/volume-6_slice_20.jpg
#   inflating: content/train_images/tumor/volume-8_slice_88.jpg
#   inflating: content/train_images/tumor/volume-25_slice_222.jpg
#   inflating: content/train_images/tumor/volume-9_slice_508.jpg
#   inflating: content/train_images/tumor/volume-22_slice_144.jpg
#   inflating: content/train_images/tumor/volume-20_slice_408.jpg
#   inflating: content/train_images/tumor/volume-20_slice_420.jpg
#   inflating: content/train_images/tumor/volume-49_slice_244.jpg
#   inflating: content/train_images/tumor/volume-19_slice_302.jpg
#   inflating: content/train_images/tumor/volume-20_slice_264.jpg
#   inflating: content/train_images/tumor/volume-11_slice_220.jpg
#   inflating: content/train_images/tumor/volume-9_slice_4.jpg
#   inflating: content/train_images/tumor/volume-24_slice_250.jpg
#   inflating: content/train_images/tumor/volume-12_slice_372.jpg
#   inflating: content/train_images/tumor/volume-19_slice_366.jpg
#   inflating: content/train_images/tumor/volume-28_slice_58.jpg
#   inflating: content/train_images/tumor/volume-5_slice_82.jpg
#   inflating: content/train_images/tumor/volume-23_slice_256.jpg
#   inflating: content/train_images/tumor/volume-36_slice_90.jpg
#   inflating: content/train_images/tumor/volume-27_slice_704.jpg
#   inflating: content/train_images/tumor/volume-5_slice_212.jpg
#   inflating: content/train_images/tumor/volume-33_slice_76.jpg
#   inflating: content/train_images/tumor/volume-6_slice_44.jpg
#   inflating: content/train_images/tumor/volume-2_slice_222.jpg
#   inflating: content/train_images/tumor/volume-24_slice_10.jpg
#   inflating: content/train_images/tumor/volume-25_slice_546.jpg
#   inflating: content/train_images/tumor/volume-3_slice_30.jpg
#   inflating: content/train_images/tumor/volume-14_slice_126.jpg
#   inflating: content/train_images/tumor/volume-36_slice_78.jpg
#   inflating: content/train_images/tumor/volume-8_slice_468.jpg
#   inflating: content/train_images/tumor/volume-15_slice_416.jpg
#   inflating: content/train_images/tumor/volume-17_slice_444.jpg
#   inflating: content/train_images/tumor/volume-17_slice_116.jpg
#   inflating: content/train_images/tumor/volume-24_slice_14.jpg
#   inflating: content/train_images/tumor/volume-13_slice_164.jpg
#   inflating: content/train_images/tumor/volume-23_slice_94.jpg
#   inflating: content/train_images/tumor/volume-29_slice_154.jpg
#   inflating: content/train_images/tumor/volume-4_slice_226.jpg
#   inflating: content/train_images/tumor/volume-2_slice_102.jpg
#   inflating: content/train_images/tumor/volume-8_slice_102.jpg
#   inflating: content/train_images/tumor/volume-15_slice_274.jpg
#   inflating: content/train_images/tumor/volume-16_slice_8.jpg
#   inflating: content/train_images/tumor/volume-8_slice_462.jpg
#   inflating: content/train_images/tumor/volume-20_slice_352.jpg
#   inflating: content/train_images/tumor/volume-48_slice_236.jpg
#   inflating: content/train_images/tumor/volume-4_slice_254.jpg
#   inflating: content/train_images/tumor/volume-36_slice_36.jpg
#   inflating: content/train_images/tumor/volume-17_slice_130.jpg
#   inflating: content/train_images/tumor/volume-43_slice_96.jpg
#   inflating: content/train_images/tumor/volume-9_slice_222.jpg
#   inflating: content/train_images/tumor/volume-27_slice_94.jpg
#   inflating: content/train_images/tumor/volume-26_slice_374.jpg
#   inflating: content/train_images/tumor/volume-17_slice_534.jpg
#   inflating: content/train_images/tumor/volume-4_slice_186.jpg
#   inflating: content/train_images/tumor/volume-12_slice_256.jpg
#   inflating: content/train_images/tumor/volume-17_slice_120.jpg
#   inflating: content/train_images/tumor/volume-2_slice_186.jpg
#   inflating: content/train_images/tumor/volume-11_slice_264.jpg
#   inflating: content/train_images/tumor/volume-25_slice_18.jpg
#   inflating: content/train_images/tumor/volume-12_slice_248.jpg
#   inflating: content/train_images/tumor/volume-15_slice_246.jpg
#   inflating: content/train_images/tumor/volume-27_slice_654.jpg
#   inflating: content/train_images/tumor/volume-17_slice_730.jpg
#   inflating: content/train_images/tumor/volume-17_slice_656.jpg
#   inflating: content/train_images/tumor/volume-19_slice_540.jpg
#   inflating: content/train_images/tumor/volume-3_slice_94.jpg
#   inflating: content/train_images/tumor/volume-22_slice_152.jpg
#   inflating: content/train_images/tumor/volume-8_slice_374.jpg
#   inflating: content/train_images/tumor/volume-11_slice_462.jpg
#   inflating: content/train_images/tumor/volume-16_slice_524.jpg
#   inflating: content/train_images/tumor/volume-16_slice_146.jpg
#   inflating: content/train_images/tumor/volume-48_slice_238.jpg
#   inflating: content/train_images/tumor/volume-18_slice_550.jpg
#   inflating: content/train_images/tumor/volume-15_slice_384.jpg
#   inflating: content/train_images/tumor/volume-27_slice_60.jpg
#   inflating: content/train_images/tumor/volume-24_slice_86.jpg
#   inflating: content/train_images/tumor/volume-6_slice_334.jpg
#   inflating: content/train_images/tumor/volume-3_slice_68.jpg
#   inflating: content/train_images/tumor/volume-49_slice_108.jpg
#   inflating: content/train_images/tumor/volume-3_slice_246.jpg
#   inflating: content/train_images/tumor/volume-37_slice_106.jpg
#   inflating: content/train_images/tumor/volume-21_slice_434.jpg
#   inflating: content/train_images/tumor/volume-8_slice_426.jpg
#   inflating: content/train_images/tumor/volume-20_slice_60.jpg
#   inflating: content/train_images/tumor/volume-49_slice_14.jpg
#   inflating: content/train_images/tumor/volume-7_slice_148.jpg
#   inflating: content/train_images/tumor/volume-23_slice_72.jpg
#   inflating: content/train_images/tumor/volume-24_slice_184.jpg
#   inflating: content/train_images/tumor/volume-26_slice_590.jpg
#   inflating: content/train_images/tumor/volume-20_slice_190.jpg
#   inflating: content/train_images/tumor/volume-13_slice_582.jpg
#   inflating: content/train_images/tumor/volume-3_slice_392.jpg
#   inflating: content/train_images/tumor/volume-4_slice_54.jpg
#   inflating: content/train_images/tumor/volume-42_slice_40.jpg
#   inflating: content/train_images/tumor/volume-13_slice_596.jpg
#   inflating: content/train_images/tumor/volume-17_slice_280.jpg
#   inflating: content/train_images/tumor/volume-45_slice_40.jpg
#   inflating: content/train_images/tumor/volume-5_slice_102.jpg
#   inflating: content/train_images/tumor/volume-18_slice_726.jpg
#   inflating: content/train_images/tumor/volume-3_slice_62.jpg
#   inflating: content/train_images/tumor/volume-12_slice_316.jpg
#   inflating: content/train_images/tumor/volume-4_slice_124.jpg
#   inflating: content/train_images/tumor/volume-5_slice_376.jpg
#   inflating: content/train_images/tumor/volume-39_slice_24.jpg
#   inflating: content/train_images/tumor/volume-16_slice_614.jpg
#   inflating: content/train_images/tumor/volume-5_slice_488.jpg
#   inflating: content/train_images/tumor/volume-2_slice_216.jpg
#   inflating: content/train_images/tumor/volume-27_slice_372.jpg
#   inflating: content/train_images/tumor/volume-4_slice_610.jpg
#   inflating: content/train_images/tumor/volume-9_slice_370.jpg
#   inflating: content/train_images/tumor/volume-21_slice_150.jpg
#   inflating: content/train_images/tumor/volume-19_slice_184.jpg
#   inflating: content/train_images/tumor/volume-10_slice_222.jpg
#   inflating: content/train_images/tumor/volume-48_slice_0.jpg
#   inflating: content/train_images/tumor/volume-7_slice_430.jpg
#   inflating: content/train_images/tumor/volume-19_slice_456.jpg
#   inflating: content/train_images/tumor/volume-15_slice_258.jpg
#   inflating: content/train_images/tumor/volume-39_slice_76.jpg
#   inflating: content/train_images/tumor/volume-23_slice_160.jpg
#   inflating: content/train_images/tumor/volume-7_slice_466.jpg
#   inflating: content/train_images/tumor/volume-15_slice_374.jpg
#   inflating: content/train_images/tumor/volume-4_slice_590.jpg
#   inflating: content/train_images/tumor/volume-20_slice_278.jpg
#   inflating: content/train_images/tumor/volume-11_slice_386.jpg
#   inflating: content/train_images/tumor/volume-27_slice_534.jpg
#   inflating: content/train_images/tumor/volume-2_slice_236.jpg
#   inflating: content/train_images/tumor/volume-42_slice_54.jpg
#   inflating: content/train_images/tumor/volume-37_slice_22.jpg
#   inflating: content/train_images/tumor/volume-17_slice_178.jpg
#   inflating: content/train_images/tumor/volume-21_slice_402.jpg
#   inflating: content/train_images/tumor/volume-14_slice_166.jpg
#   inflating: content/train_images/tumor/volume-4_slice_502.jpg
#   inflating: content/train_images/tumor/volume-18_slice_484.jpg
#   inflating: content/train_images/tumor/volume-26_slice_502.jpg
#   inflating: content/train_images/tumor/volume-25_slice_398.jpg
#   inflating: content/train_images/tumor/volume-14_slice_576.jpg
#   inflating: content/train_images/tumor/volume-31_slice_48.jpg
#   inflating: content/train_images/tumor/volume-10_slice_110.jpg
#   inflating: content/train_images/tumor/volume-20_slice_416.jpg
#   inflating: content/train_images/tumor/volume-17_slice_478.jpg
#   inflating: content/train_images/tumor/volume-6_slice_96.jpg
#   inflating: content/train_images/tumor/volume-25_slice_154.jpg
#   inflating: content/train_images/tumor/volume-42_slice_116.jpg
#   inflating: content/train_images/tumor/volume-3_slice_492.jpg
#   inflating: content/train_images/tumor/volume-17_slice_462.jpg
#   inflating: content/train_images/tumor/volume-5_slice_504.jpg
#   inflating: content/train_images/tumor/volume-18_slice_238.jpg
#   inflating: content/train_images/tumor/volume-26_slice_552.jpg
#   inflating: content/train_images/tumor/volume-8_slice_540.jpg
#   inflating: content/train_images/tumor/volume-6_slice_246.jpg
#   inflating: content/train_images/tumor/volume-25_slice_390.jpg
#   inflating: content/train_images/tumor/volume-26_slice_300.jpg
#   inflating: content/train_images/tumor/volume-24_slice_40.jpg
#   inflating: content/train_images/tumor/volume-18_slice_206.jpg
#   inflating: content/train_images/tumor/volume-10_slice_256.jpg
#   inflating: content/train_images/tumor/volume-24_slice_134.jpg
#   inflating: content/train_images/tumor/volume-25_slice_550.jpg
#   inflating: content/train_images/tumor/volume-27_slice_132.jpg
#   inflating: content/train_images/tumor/volume-18_slice_548.jpg
#   inflating: content/train_images/tumor/volume-16_slice_680.jpg
#   inflating: content/train_images/tumor/volume-19_slice_278.jpg
#   inflating: content/train_images/tumor/volume-5_slice_368.jpg
#   inflating: content/train_images/tumor/volume-3_slice_452.jpg
#   inflating: content/train_images/tumor/volume-23_slice_348.jpg
#   inflating: content/train_images/tumor/volume-27_slice_540.jpg
#   inflating: content/train_images/tumor/volume-9_slice_186.jpg
#   inflating: content/train_images/tumor/volume-9_slice_184.jpg
#   inflating: content/train_images/tumor/volume-27_slice_44.jpg
#   inflating: content/train_images/tumor/volume-18_slice_634.jpg
#   inflating: content/train_images/tumor/volume-18_slice_216.jpg
#   inflating: content/train_images/tumor/volume-6_slice_274.jpg
#   inflating: content/train_images/tumor/volume-15_slice_76.jpg
#   inflating: content/train_images/tumor/volume-16_slice_120.jpg
#   inflating: content/train_images/tumor/volume-29_slice_24.jpg
#   inflating: content/train_images/tumor/volume-4_slice_674.jpg
#   inflating: content/train_images/tumor/volume-15_slice_206.jpg
#   inflating: content/train_images/tumor/volume-18_slice_338.jpg
#   inflating: content/train_images/tumor/volume-14_slice_302.jpg
#   inflating: content/train_images/tumor/volume-17_slice_704.jpg
#   inflating: content/train_images/tumor/volume-22_slice_110.jpg
#   inflating: content/train_images/tumor/volume-24_slice_142.jpg
#   inflating: content/train_images/tumor/volume-3_slice_324.jpg
#   inflating: content/train_images/tumor/volume-18_slice_208.jpg
#   inflating: content/train_images/tumor/volume-16_slice_184.jpg
#   inflating: content/train_images/tumor/volume-26_slice_356.jpg
#   inflating: content/train_images/tumor/volume-39_slice_58.jpg
#   inflating: content/train_images/tumor/volume-48_slice_34.jpg
#   inflating: content/train_images/tumor/volume-50_slice_224.jpg
#   inflating: content/train_images/tumor/volume-36_slice_44.jpg
#   inflating: content/train_images/tumor/volume-13_slice_8.jpg
#   inflating: content/train_images/tumor/volume-23_slice_234.jpg
#   inflating: content/train_images/tumor/volume-44_slice_34.jpg
#   inflating: content/train_images/tumor/volume-5_slice_172.jpg
#   inflating: content/train_images/tumor/volume-24_slice_262.jpg
#   inflating: content/train_images/tumor/volume-14_slice_290.jpg
#   inflating: content/train_images/tumor/volume-27_slice_172.jpg
#   inflating: content/train_images/tumor/volume-20_slice_368.jpg
#   inflating: content/train_images/tumor/volume-33_slice_36.jpg
#   inflating: content/train_images/tumor/volume-44_slice_118.jpg
#   inflating: content/train_images/tumor/volume-23_slice_372.jpg
#   inflating: content/train_images/tumor/volume-7_slice_452.jpg
#   inflating: content/train_images/tumor/volume-27_slice_366.jpg
#   inflating: content/train_images/tumor/volume-13_slice_264.jpg
#   inflating: content/train_images/tumor/volume-16_slice_174.jpg
#   inflating: content/train_images/tumor/volume-11_slice_66.jpg
#   inflating: content/train_images/tumor/volume-24_slice_176.jpg
#   inflating: content/train_images/tumor/volume-26_slice_212.jpg
#   inflating: content/train_images/tumor/volume-14_slice_270.jpg
#   inflating: content/train_images/tumor/volume-24_slice_102.jpg
#   inflating: content/train_images/tumor/volume-2_slice_2.jpg
#   inflating: content/train_images/tumor/volume-9_slice_430.jpg
#   inflating: content/train_images/tumor/volume-4_slice_382.jpg
#   inflating: content/train_images/tumor/volume-2_slice_306.jpg
#   inflating: content/train_images/tumor/volume-16_slice_452.jpg
#   inflating: content/train_images/tumor/volume-18_slice_678.jpg
#   inflating: content/train_images/tumor/volume-27_slice_392.jpg
#   inflating: content/train_images/tumor/volume-4_slice_428.jpg
#   inflating: content/train_images/tumor/volume-48_slice_112.jpg
#   inflating: content/train_images/tumor/volume-8_slice_492.jpg
#   inflating: content/train_images/tumor/volume-9_slice_220.jpg
#   inflating: content/train_images/tumor/volume-10_slice_310.jpg
#   inflating: content/train_images/tumor/volume-25_slice_272.jpg
#   inflating: content/train_images/tumor/volume-15_slice_180.jpg
#   inflating: content/train_images/tumor/volume-37_slice_32.jpg
#   inflating: content/train_images/tumor/volume-45_slice_16.jpg
#   inflating: content/train_images/tumor/volume-8_slice_174.jpg
#   inflating: content/train_images/tumor/volume-10_slice_486.jpg
#   inflating: content/train_images/tumor/volume-27_slice_802.jpg
#   inflating: content/train_images/tumor/volume-48_slice_130.jpg
#   inflating: content/train_images/tumor/volume-10_slice_84.jpg
#   inflating: content/train_images/tumor/volume-2_slice_112.jpg
#   inflating: content/train_images/tumor/volume-49_slice_96.jpg
#   inflating: content/train_images/tumor/volume-48_slice_54.jpg
#   inflating: content/train_images/tumor/volume-45_slice_24.jpg
#   inflating: content/train_images/tumor/volume-42_slice_84.jpg
#   inflating: content/train_images/tumor/volume-27_slice_808.jpg
#   inflating: content/train_images/tumor/volume-18_slice_732.jpg
#   inflating: content/train_images/tumor/volume-18_slice_400.jpg
#   inflating: content/train_images/tumor/volume-20_slice_310.jpg
#   inflating: content/train_images/tumor/volume-26_slice_648.jpg
#   inflating: content/train_images/tumor/volume-5_slice_344.jpg
#   inflating: content/train_images/tumor/volume-3_slice_486.jpg
#   inflating: content/train_images/tumor/volume-42_slice_80.jpg
#   inflating: content/train_images/tumor/volume-14_slice_160.jpg
#   inflating: content/train_images/tumor/volume-19_slice_462.jpg
#   inflating: content/train_images/tumor/volume-19_slice_320.jpg
#   inflating: content/train_images/tumor/volume-23_slice_292.jpg
#   inflating: content/train_images/tumor/volume-46_slice_114.jpg
#   inflating: content/train_images/tumor/volume-14_slice_108.jpg
#   inflating: content/train_images/tumor/volume-4_slice_506.jpg
#   inflating: content/train_images/tumor/volume-4_slice_332.jpg
#   inflating: content/train_images/tumor/volume-48_slice_16.jpg
#   inflating: content/train_images/tumor/volume-10_slice_198.jpg
#   inflating: content/train_images/tumor/volume-11_slice_198.jpg
#   inflating: content/train_images/tumor/volume-13_slice_256.jpg
#   inflating: content/train_images/tumor/volume-25_slice_224.jpg
#   inflating: content/train_images/tumor/volume-3_slice_322.jpg
#   inflating: content/train_images/tumor/volume-17_slice_642.jpg
#   inflating: content/train_images/tumor/volume-8_slice_128.jpg
#   inflating: content/train_images/tumor/volume-8_slice_64.jpg
#   inflating: content/train_images/tumor/volume-30_slice_132.jpg
#   inflating: content/train_images/tumor/volume-20_slice_220.jpg
#   inflating: content/train_images/tumor/volume-20_slice_372.jpg
#   inflating: content/train_images/tumor/volume-4_slice_8.jpg
#   inflating: content/train_images/tumor/volume-27_slice_838.jpg
#   inflating: content/train_images/tumor/volume-5_slice_254.jpg
#   inflating: content/train_images/tumor/volume-15_slice_256.jpg
#   inflating: content/train_images/tumor/volume-10_slice_220.jpg
# ...
#   inflating: content/train_images/normal/volume-38_slice_46.jpg
#   inflating: content/train_images/normal/volume-32_slice_112.jpg
#   inflating: content/train_images/normal/volume-41_slice_90.jpg
#   inflating: content/train_images/normal/volume-47_slice_166.jpg
#   inflating: content/train_images/normal/volume-47_slice_132.jpg
#   inflating: content/train_images/normal/volume-32_slice_68.jpg
#   inflating: content/train_images/normal/volume-34_slice_6.jpg
#   inflating: content/train_images/normal/volume-34_slice_22.jpg
#   inflating: content/train_images/normal/volume-41_slice_4.jpg
#   inflating: content/train_images/normal/volume-47_slice_160.jpg
#   inflating: content/train_images/normal/volume-38_slice_94.jpg
#   inflating: content/train_images/normal/volume-34_slice_112.jpg
#   inflating: content/train_images/normal/volume-32_slice_124.jpg
#   inflating: content/train_images/normal/volume-34_slice_68.jpg
#   inflating: content/train_images/normal/volume-32_slice_20.jpg
#   inflating: content/train_images/normal/volume-47_slice_122.jpg
#   inflating: content/train_images/normal/volume-38_slice_106.jpg
#   inflating: content/train_images/normal/volume-47_slice_212.jpg
#   inflating: content/train_images/normal/volume-47_slice_84.jpg
#   inflating: content/train_images/normal/volume-41_slice_80.jpg
#   inflating: content/train_images/normal/volume-47_slice_178.jpg
#   inflating: content/train_images/normal/volume-38_slice_74.jpg
#   inflating: content/train_images/normal/volume-34_slice_34.jpg
#   inflating: content/train_images/normal/volume-34_slice_84.jpg
#   inflating: content/train_images/normal/volume-34_slice_114.jpg
#   inflating: content/train_images/normal/volume-47_slice_34.jpg
#   inflating: content/train_images/normal/volume-34_slice_120.jpg
#   inflating: content/train_images/normal/volume-32_slice_14.jpg
#   inflating: content/train_images/normal/volume-38_slice_122.jpg
#   inflating: content/train_images/normal/volume-32_slice_118.jpg
#   inflating: content/train_images/normal/volume-34_slice_74.jpg
#   inflating: content/train_images/normal/volume-47_slice_116.jpg
#   inflating: content/train_images/normal/volume-32_slice_62.jpg
#   inflating: content/train_images/normal/volume-47_slice_48.jpg
#   inflating: content/train_images/normal/volume-47_slice_8.jpg
#   inflating: content/train_images/normal/volume-38_slice_8.jpg
#   inflating: content/train_images/normal/volume-32_slice_116.jpg
#   inflating: content/train_images/normal/volume-41_slice_14.jpg
#   inflating: content/train_images/normal/volume-32_slice_114.jpg
#   inflating: content/train_images/normal/volume-38_slice_118.jpg
#   inflating: content/train_images/normal/volume-38_slice_98.jpg
#   inflating: content/train_images/normal/volume-34_slice_18.jpg
#   inflating: content/train_images/normal/volume-34_slice_8.jpg
#   inflating: content/train_images/normal/volume-47_slice_16.jpg
#   inflating: content/train_images/normal/volume-41_slice_36.jpg
#   inflating: content/train_images/normal/volume-34_slice_70.jpg
#   inflating: content/train_images/normal/volume-41_slice_24.jpg
#   inflating: content/train_images/normal/volume-34_slice_48.jpg
#   inflating: content/train_images/normal/volume-34_slice_62.jpg
#   inflating: content/train_images/normal/volume-47_slice_126.jpg
#   inflating: content/train_images/normal/volume-41_slice_20.jpg
#   inflating: content/train_images/normal/volume-47_slice_18.jpg
#   inflating: content/train_images/normal/volume-41_slice_82.jpg
#   inflating: content/train_images/normal/volume-47_slice_46.jpg
#   inflating: content/train_images/normal/volume-41_slice_94.jpg
#   inflating: content/train_images/normal/volume-34_slice_72.jpg
#   inflating: content/train_images/normal/volume-41_slice_100.jpg
#   inflating: content/train_images/normal/volume-41_slice_32.jpg
#   inflating: content/train_images/normal/volume-34_slice_42.jpg
#   inflating: content/train_images/normal/volume-41_slice_34.jpg
#   inflating: content/train_images/normal/volume-38_slice_92.jpg
#   inflating: content/train_images/normal/volume-47_slice_76.jpg
#   inflating: content/train_images/normal/volume-47_slice_62.jpg
#   inflating: content/train_images/normal/volume-47_slice_10.jpg
#   inflating: content/train_images/normal/volume-47_slice_74.jpg
#   inflating: content/train_images/normal/volume-47_slice_150.jpg
#   inflating: content/train_images/normal/volume-47_slice_182.jpg
#   inflating: content/train_images/normal/volume-41_slice_30.jpg
#   inflating: content/train_images/normal/volume-32_slice_12.jpg
#   inflating: content/train_images/normal/volume-47_slice_88.jpg
#   inflating: content/train_images/normal/volume-41_slice_98.jpg
#   inflating: content/train_images/normal/volume-47_slice_162.jpg
#   inflating: content/train_images/normal/volume-47_slice_92.jpg
#   inflating: content/train_images/normal/volume-32_slice_40.jpg
#   inflating: content/train_images/normal/volume-38_slice_12.jpg
#   inflating: content/train_images/normal/volume-34_slice_100.jpg
#   inflating: content/train_images/normal/volume-47_slice_220.jpg
#   inflating: content/train_images/normal/volume-47_slice_194.jpg
#   inflating: content/train_images/normal/volume-47_slice_86.jpg
#   inflating: content/train_images/normal/volume-32_slice_50.jpg
#   inflating: content/train_images/normal/volume-41_slice_108.jpg
#   inflating: content/train_images/normal/volume-47_slice_174.jpg
#   inflating: content/train_images/normal/volume-47_slice_190.jpg
#   inflating: content/train_images/normal/volume-47_slice_6.jpg
#   inflating: content/train_images/normal/volume-32_slice_44.jpg
#   inflating: content/train_images/normal/volume-34_slice_110.jpg
#   inflating: content/train_images/normal/volume-34_slice_2.jpg
#   inflating: content/train_images/normal/volume-47_slice_112.jpg
#   inflating: content/train_images/normal/volume-47_slice_106.jpg
#   inflating: content/train_images/normal/volume-32_slice_48.jpg
#   inflating: content/train_images/normal/volume-38_slice_62.jpg
#   inflating: content/train_images/normal/volume-32_slice_36.jpg
#   inflating: content/train_images/normal/volume-38_slice_30.jpg
#   inflating: content/train_images/normal/volume-34_slice_128.jpg
#   inflating: content/train_images/normal/volume-32_slice_120.jpg
#   inflating: content/train_images/normal/volume-32_slice_38.jpg
#   inflating: content/train_images/normal/volume-34_slice_82.jpg
#   inflating: content/train_images/normal/volume-41_slice_18.jpg
#   inflating: content/train_images/normal/volume-34_slice_118.jpg
#   inflating: content/train_images/normal/volume-34_slice_60.jpg
#   inflating: content/train_images/normal/volume-32_slice_42.jpg
#   inflating: content/train_images/normal/volume-41_slice_8.jpg
#   inflating: content/train_images/normal/volume-47_slice_96.jpg
#   inflating: content/train_images/normal/volume-47_slice_44.jpg
#   inflating: content/train_images/normal/volume-47_slice_206.jpg
#   inflating: content/train_images/normal/volume-34_slice_88.jpg
#   inflating: content/train_images/normal/volume-47_slice_134.jpg
#   inflating: content/train_images/normal/volume-38_slice_16.jpg
#   inflating: content/train_images/normal/volume-32_slice_134.jpg
#   inflating: content/train_images/normal/volume-38_slice_52.jpg
#   inflating: content/train_images/normal/volume-32_slice_8.jpg
#   inflating: content/train_images/normal/volume-32_slice_76.jpg
#   inflating: content/train_images/normal/volume-47_slice_164.jpg
#   inflating: content/train_images/normal/volume-47_slice_100.jpg
#   inflating: content/train_images/normal/volume-32_slice_100.jpg
#   inflating: content/train_images/normal/volume-32_slice_16.jpg
#   inflating: content/train_images/normal/volume-34_slice_106.jpg
#   inflating: content/train_images/normal/volume-38_slice_26.jpg
#   inflating: content/train_images/normal/volume-32_slice_104.jpg
#   inflating: content/train_images/normal/volume-47_slice_208.jpg
#   inflating: content/train_images/normal/volume-41_slice_2.jpg
#   inflating: content/train_images/normal/volume-38_slice_82.jpg
#   inflating: content/train_images/normal/volume-47_slice_158.jpg
#   inflating: content/train_images/normal/volume-47_slice_216.jpg
#   inflating: content/train_images/normal/volume-47_slice_104.jpg
#   inflating: content/train_images/normal/volume-32_slice_86.jpg
#   inflating: content/train_images/normal/volume-34_slice_130.jpg
#   inflating: content/train_images/normal/volume-38_slice_58.jpg
#   inflating: content/train_images/normal/volume-47_slice_176.jpg
#   inflating: content/train_images/normal/volume-34_slice_104.jpg
#   inflating: content/train_images/normal/volume-38_slice_36.jpg
#   inflating: content/train_images/normal/volume-47_slice_56.jpg
#   inflating: content/train_images/normal/volume-47_slice_26.jpg
#   inflating: content/train_images/normal/volume-47_slice_218.jpg
#   inflating: content/train_images/normal/volume-34_slice_148.jpg
#   inflating: content/train_images/normal/volume-38_slice_108.jpg
#   inflating: content/train_images/normal/volume-34_slice_52.jpg
#   inflating: content/train_images/normal/volume-32_slice_130.jpg
#   inflating: content/train_images/normal/volume-47_slice_170.jpg
#   inflating: content/train_images/normal/volume-32_slice_52.jpg
#   inflating: content/train_images/normal/volume-47_slice_94.jpg
#   inflating: content/train_images/normal/volume-47_slice_58.jpg
#   inflating: content/train_images/normal/volume-32_slice_26.jpg
#   inflating: content/train_images/normal/volume-32_slice_60.jpg
#   inflating: content/train_images/normal/volume-38_slice_114.jpg
#   inflating: content/train_images/normal/volume-32_slice_64.jpg
#   inflating: content/train_images/normal/volume-34_slice_146.jpg
#   inflating: content/train_images/normal/volume-38_slice_66.jpg
#   inflating: content/train_images/normal/volume-47_slice_14.jpg
#   inflating: content/train_images/normal/volume-41_slice_6.jpg
#   inflating: content/train_images/normal/volume-34_slice_144.jpg
#   inflating: content/train_images/normal/volume-41_slice_10.jpg
#   inflating: content/train_images/normal/volume-34_slice_66.jpg
#   inflating: content/train_images/normal/volume-47_slice_108.jpg
#   inflating: content/train_images/normal/volume-38_slice_68.jpg
#   inflating: content/train_images/normal/volume-32_slice_6.jpg
#   inflating: content/train_images/normal/volume-38_slice_56.jpg
#   inflating: content/train_images/normal/volume-34_slice_92.jpg
#   inflating: content/train_images/normal/volume-38_slice_18.jpg
#   inflating: content/train_images/normal/volume-34_slice_134.jpg
#   inflating: content/train_images/normal/volume-47_slice_4.jpg
#   inflating: content/train_images/normal/volume-34_slice_0.jpg
#   inflating: content/train_images/normal/volume-47_slice_222.jpg
#   inflating: content/train_images/normal/volume-41_slice_56.jpg
#   inflating: content/train_images/normal/volume-47_slice_90.jpg
#   inflating: content/train_images/normal/volume-47_slice_210.jpg
#   inflating: content/train_images/normal/volume-38_slice_116.jpg
#   inflating: content/train_images/normal/volume-34_slice_44.jpg
#   inflating: content/train_images/normal/volume-38_slice_96.jpg
#   inflating: content/train_images/normal/volume-41_slice_54.jpg
#   inflating: content/train_images/normal/volume-34_slice_102.jpg
#   inflating: content/train_images/normal/volume-47_slice_172.jpg
#   inflating: content/train_images/normal/volume-32_slice_2.jpg
#   inflating: content/train_images/normal/volume-41_slice_112.jpg
#   inflating: content/train_images/normal/volume-38_slice_90.jpg
#   inflating: content/train_images/normal/volume-47_slice_110.jpg
#   inflating: content/train_images/normal/volume-47_slice_196.jpg
#   inflating: content/train_images/normal/volume-34_slice_50.jpg
#   inflating: content/train_images/normal/volume-34_slice_38.jpg
#   inflating: content/train_images/normal/volume-32_slice_88.jpg
#   inflating: content/train_images/normal/volume-41_slice_0.jpg
#   inflating: content/train_images/normal/volume-38_slice_54.jpg
#   inflating: content/train_images/normal/volume-38_slice_102.jpg
#   inflating: content/train_images/normal/volume-34_slice_142.jpg
#   inflating: content/train_images/normal/volume-38_slice_126.jpg
#   inflating: content/train_images/normal/volume-47_slice_0.jpg
#   inflating: content/train_images/normal/volume-34_slice_16.jpg
#   inflating: content/train_images/normal/volume-47_slice_192.jpg
#   inflating: content/train_images/normal/volume-32_slice_94.jpg
#   inflating: content/train_images/normal/volume-34_slice_32.jpg
#   inflating: content/train_images/normal/volume-38_slice_104.jpg
#   inflating: content/train_images/normal/volume-47_slice_50.jpg
#   inflating: content/train_images/normal/volume-34_slice_54.jpg
#   inflating: content/train_images/normal/volume-41_slice_40.jpg
#   inflating: content/train_images/normal/volume-38_slice_124.jpg
#   inflating: content/train_images/normal/volume-47_slice_130.jpg
#   inflating: content/train_images/normal/volume-38_slice_6.jpg
#   inflating: content/train_images/normal/volume-41_slice_48.jpg
#   inflating: content/train_images/normal/volume-38_slice_112.jpg
#   inflating: content/train_images/normal/volume-47_slice_24.jpg
#   inflating: content/train_images/normal/volume-47_slice_224.jpg
#   inflating: content/train_images/normal/volume-41_slice_26.jpg
#   inflating: content/train_images/normal/volume-32_slice_74.jpg
#   inflating: content/train_images/normal/volume-38_slice_0.jpg
#   inflating: content/train_images/normal/volume-38_slice_64.jpg
#   inflating: content/train_images/normal/volume-32_slice_122.jpg
#   inflating: content/train_images/normal/volume-41_slice_106.jpg
#   inflating: content/train_images/normal/volume-41_slice_16.jpg
#   inflating: content/train_images/normal/volume-32_slice_10.jpg
#   inflating: content/train_images/normal/volume-32_slice_28.jpg
#   inflating: content/train_images/normal/volume-47_slice_72.jpg
#   inflating: content/train_images/normal/volume-47_slice_214.jpg
#   inflating: content/train_images/normal/volume-34_slice_4.jpg
#   inflating: content/train_images/normal/volume-41_slice_96.jpg
#   inflating: content/train_images/normal/volume-38_slice_78.jpg
#   inflating: content/train_images/normal/volume-32_slice_108.jpg
#   inflating: content/train_images/normal/volume-47_slice_204.jpg
#   inflating: content/train_images/normal/volume-32_slice_72.jpg
#   inflating: content/train_images/normal/volume-47_slice_142.jpg
#   inflating: content/train_images/normal/volume-41_slice_86.jpg
#   inflating: content/train_images/normal/volume-47_slice_42.jpg
#   inflating: content/train_images/normal/volume-47_slice_32.jpg
#   inflating: content/train_images/normal/volume-47_slice_146.jpg
#   inflating: content/train_images/normal/volume-47_slice_22.jpg
#   inflating: content/train_images/normal/volume-38_slice_42.jpg
#   inflating: content/train_images/normal/volume-41_slice_76.jpg
#   inflating: content/train_images/normal/volume-41_slice_102.jpg
#   inflating: content/train_images/normal/volume-41_slice_68.jpg
#   inflating: content/train_images/normal/volume-32_slice_102.jpg
#   inflating: content/train_images/normal/volume-47_slice_98.jpg
#   inflating: content/train_images/normal/volume-47_slice_38.jpg
#   inflating: content/train_images/normal/volume-47_slice_128.jpg
#   inflating: content/train_images/normal/volume-38_slice_60.jpg
#   inflating: content/train_images/normal/volume-32_slice_80.jpg
#   inflating: content/train_images/normal/volume-34_slice_46.jpg
#   inflating: content/train_images/normal/volume-47_slice_156.jpg
#   inflating: content/train_images/normal/volume-41_slice_52.jpg
#   inflating: content/train_images/normal/volume-32_slice_32.jpg
#   inflating: content/train_images/normal/volume-34_slice_94.jpg
#   inflating: content/train_images/normal/volume-32_slice_30.jpg
#   inflating: content/train_images/normal/volume-47_slice_78.jpg

# %%
import warnings
warnings.filterwarnings('ignore') #this code suppresses any warnings that might be issued during the execution of the Python script. It's often used when you want to suppress certain types of warnings that you know won't affect the functionality of your code, or when you want to keep the output clean and free of warning messages.

# %%
import os #offers a wide range of functions for interacting with the operating system, such as working with files and directories.
import shutil #provides a higher-level interface for file operations, offering functions to copy, move, and delete files and directories.
import random # It provides functions for generating random integers, selecting random elements from a sequence, shuffling sequences randomly, and more.

ROOT_DIR = "/content/Liver tumour data/Liver tumour dataset" #root directory path
TRAIN_DIR = "./train" #new directory train
TEST_DIR = "./test" #new directory test
VAL_DIR = "./validation" #new directory validation
TRAIN_RATIO = 0.7 #70% of the data will be used for training.
VAL_RATIO = 0.15 #15% of the data will be used for validation

if not os.path.exists(TRAIN_DIR): #if Train directory doesn't exists make a new one
    os.makedirs(TRAIN_DIR)
if not os.path.exists(TEST_DIR): #if Test directory doesn't exists make a new one
    os.makedirs(TEST_DIR)
if not os.path.exists(VAL_DIR): #if Validation directory doesn't exists make a new one
    os.makedirs(VAL_DIR)

for class_dir in os.listdir(ROOT_DIR):
    if os.path.isdir(os.path.join(ROOT_DIR, class_dir)):
        images = os.listdir(os.path.join(ROOT_DIR, class_dir))
        random.shuffle(images)  # Shuffle images to randomize the selection

        # Split images based on the ratios
        train_split_index = int(len(images) * TRAIN_RATIO)
        val_split_index = int(len(images) * (TRAIN_RATIO + VAL_RATIO))

        train_images = images[:train_split_index]
        val_images = images[train_split_index:val_split_index]
        test_images = images[val_split_index:]

        # Create class directories in train, test, and validation directories if they don't exist
        train_class_dir = os.path.join(TRAIN_DIR, class_dir)
        test_class_dir = os.path.join(TEST_DIR, class_dir)
        val_class_dir = os.path.join(VAL_DIR, class_dir)
        if not os.path.exists(train_class_dir):
            os.makedirs(train_class_dir)
        if not os.path.exists(test_class_dir):
            os.makedirs(test_class_dir)
        if not os.path.exists(val_class_dir):
            os.makedirs(val_class_dir)

        # Copy images to train, test, and validation directories
        for img in train_images:
            src = os.path.join(ROOT_DIR, class_dir, img)
            dst = os.path.join(train_class_dir, img)
            shutil.copy(src, dst)

        for img in val_images:
            src = os.path.join(ROOT_DIR, class_dir, img)
            dst = os.path.join(val_class_dir, img)
            shutil.copy(src, dst)

        for img in test_images:
            src = os.path.join(ROOT_DIR, class_dir, img)
            dst = os.path.join(test_class_dir, img)
            shutil.copy(src, dst)

print("Data divided into train, test, and validation sets successfully.")
# Out:
# Data divided into train, test, and validation sets successfully.

# %%
from keras.layers import Input, Lambda, Dense, Flatten # used in constructing neural network models
from keras.models import Model #for constructing arbitrary neural network architectures
from keras.applications.vgg19 import VGG19 #imports the pre-trained VGG19 model, which is a popular convolutional neural network architecture often used for image classification tasks.
from keras.applications.vgg16 import preprocess_input #preprocessing input images to be compatible with the VGG16 model.
from keras.preprocessing import image #for image preprocessing and data augmentation
from keras.preprocessing.image import ImageDataGenerator # for image preprocessing and data augmentation
from keras.models import Sequential #for constructing models layer-by-layer.
import numpy as np # used to array and numerical operations
from glob import glob #retrieve files/pathnames matching a specified pattern.
import matplotlib.pyplot as plt #used for data visualization in Python.

# %%
IMAGE_SIZE = [224, 224] #resizing image to square with both dimensions set to 224 pixels

# %%
train_path = '/content/train' #training dataset path
valid_path = '/content/test' #validation dataset path

# %%
vgg = VGG19(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
#'imagenet' means that the model will be initialized with weights pre-trained on the ImageNet dataset.
#IMAGE_SIZE + [3], which means the input shape is a tuple consisting of the dimensions specified in the IMAGE_SIZE constant (224x224 in this case) followed by the number 3, indicating that the input images are RGB (3 color channels: Red, Green, Blue).
#Setting it to False means that these layers, which are typically used for image classification on ImageNet, will not be included. This is often done when using pre-trained models for feature extraction or transfer learning, as it allows you to add your own custom layers on top of the pre-trained model.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
for layer in vgg.layers:
  layer.trainable = False #This code iterates over all the layers in the VGG19 model (vgg) and sets the trainable attribute of each layer to False.when a layer is not trainable, its parameters remain fixed, and they won't be updated during training.

# %%
folders = glob('/content/train/*') # search for folders within the directory /content/train/.The asterisk (*) is a wildcard character that matches any sequence of characters in a filename or directory name

# %%
x = Flatten()(vgg.output) #This line creates a new layer in the neural network by applying the Flatten() operation to the output of the VGG19 model (vgg.output). The Flatten() layer reshapes the output tensor from the convolutional layers into a 1D tensor, which is required as input for the subsequent fully connected layers.
# x = Dense(1000, activation='relu')(x)
prediction = Dense(len(folders), activation='softmax')(x)#This line adds a new fully connected layer to the neural network. It creates a Dense layer with the number of units equal to the number of folders found earlier (likely representing the number of classes or categories in the dataset). The activation function used is softmax, which is commonly used for multi-class classification problems as it outputs probabilities for each class.

# %%
model = Model(inputs=vgg.input, outputs=prediction) #This creates a new Model object where vgg.input is set as the input and prediction is set as the output.
#vgg.input represents the input tensor of the VGG19 model (vgg). It defines the placeholder for the input images.
#An input tensor in the context of neural networks refers to the multidimensional array of data that serves as the input to the network

# %%
model.summary() #provides summary of the model
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 20074562 (76.58 MB)
# Trainable params: 50178 (196.01 KB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %%
train_datagen = ImageDataGenerator(rescale = 1./255, #This parameter rescales the pixel values of the images. By dividing each pixel value by 255, the pixel values will be normalized to the range [0, 1]. This is a common preprocessing step in deep learning to ensure that the input values are within a similar range, which can improve training performance.
                                   shear_range = 0.2, # Shear transformation is a type of geometric transformation that tilts the shapes of objects in an image along a particular axis. This parameter specifies the range within which the shear transformation will be applied. In this case, shear_range = 0.2 means that the shear transformation will be applied with a maximum shear angle of 20 degrees.
                                   zoom_range = 0.2, # Here, zoom_range = 0.2 means that the image can be zoomed in or out by up to 20%.
                                   horizontal_flip = True) #horizontal flipping will be applied.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32, #the number of images to include in each batch. During training, the model will be updated based on the predictions made on each batch of images. Here, the batch size is set to 32.
                                                 class_mode = 'categorical') #In this case, 'categorical' indicates that the labels are one-hot encoded. Each class will have its corresponding column in the label array, with a value of 1 indicating the presence of that class and 0 indicating the absence.
# Out:
# Found 6478 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/test',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 1389 images belonging to 2 classes.

# %%
model.compile(
  loss='categorical_crossentropy', #used for multi-class classification problems where the output labels are one-hot encoded. It calculates the cross-entropy loss between the predicted probability distribution and the true probability distribution of the classes.
  optimizer='adam', #'adam' refers to the Adam optimizer, which is an adaptive learning rate optimization algorithm that is commonly used in deep learning tasks. It dynamically adjusts the learning rate during training, potentially leading to faster convergence and better performance.
  metrics=['accuracy'] #'accuracy' is a common metric used in classification problems. It calculates the proportion of correctly predicted labels compared to the total number of samples.
)

# %%
num_classes = len(os.listdir(TRAIN_DIR)) #num_classes will contain the number of classes found in the training directory. This information is often used in tasks such as image classification, where each directory corresponds to a different class, and the number of classes determines the output size of the model's final layer.

# %%
prediction = Dense(num_classes, activation='softmax')(x)

# %%
from keras.layers import Input, Dense, Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
from keras.preprocessing.image import ImageDataGenerator

# Count the number of classes based on the folders in the training directory
num_classes = len(os.listdir(TRAIN_DIR))

# Load the pre-trained VGG19 model
vgg = VGG19(input_shape=(224, 224, 3), weights='imagenet', include_top=False)

# Freeze the layers in the pre-trained VGG19 model
for layer in vgg.layers:
    layer.trainable = False

# Flatten the output of the VGG19 model
x = Flatten()(vgg.output)

# Add a dense layer with softmax activation for classification
predictions = Dense(num_classes, activation='softmax')(x)

# Create the final model
model = Model(inputs=vgg.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Create image data generators for training and testing data
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=3,
    validation_data=test_generator,
    validation_steps=len(test_generator)
)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_3 (Dense)             (None, 2)                 50178
#
# =================================================================
# Total params: 20074562 (76.58 MB)
# Trainable params: 50178 (196.01 KB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________
# Found 6478 images belonging to 2 classes.
# Found 1389 images belonging to 2 classes.
# Epoch 1/3
# 203/203 [==============================] - 53s 256ms/step - loss: 0.0848 - accuracy: 0.9821 - val_loss: 0.0101 - val_accuracy: 0.9986
# Epoch 2/3
# 203/203 [==============================] - 50s 244ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 3/3
# 203/203 [==============================] - 52s 256ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000

# %%
import tensorflow as tf

from keras.models import load_model

model.save('tumour_vgg19.h5')
